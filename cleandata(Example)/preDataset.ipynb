# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv("data_ready\dataset2.csv").head(60)  
df2 = pd.read_csv("data_ready\dataset1.csv")

# %%
df1
# Out:
#     Gender                 Budget  FreeTime  TimeAtHome     Living  \
# 0     Male         Less than 1000         3           2      House
# 1     Male      Greater than 3000        10          24      House
# 2     Male         Less than 1000         1          12      House
# 3   Female      Greater than 3000         4           2      Condo
# 4   Female  Between 1000 and 3000         1           9      House
# 5   Female         Less than 1000         0           0  Apartment
# 6     Male  Between 1000 and 3000         6          10      House
# 7     Male      Greater than 3000         2           2      House
# 8     Male         Less than 1000         8           8  Apartment
# 9     Male      Greater than 3000        26          27      House
# 10    Male  Between 1000 and 3000         8          16      House
# 11  Female      Greater than 3000         3          12      Condo
#
#    PreferQuietPet Allergies PetChoice
# 0             Yes       Yes      Fish
# 1              No        No       Dog
# 2              No        No       Cat
# 3             Yes        No       Dog
# 4             Yes       Yes     Snake
# 5              No       Yes    No pet
# 6             Yes        No     Snake
# 7             Yes       Yes   Hamster
# 8             Yes        No      Fish
# 9              No       Yes    No pet
# 10            Yes       Yes    No pet
# 11            Yes        No       Cat

# %%
df2
# Out:
#     Gender                 Budget  FreeTime  TimeAtHome     Living  \
# 0     Male  Between 1000 and 3000         1           2  Apartment
# 1   Female      Greater than 3000         2           5      House
# 2     Male  Between 1000 and 3000         3           6      Condo
# 3   Female  Between 1000 and 3000         4           3      House
# 4     Male      Greater than 3000         5           4  Apartment
# ..     ...                    ...       ...         ...        ...
# 95  Female  Between 1000 and 3000         1           2  Apartment
# 96    Male      Greater than 3000         2           5      House
# 97  Female  Between 1000 and 3000         3           6      Condo
# 98    Male  Between 1000 and 3000         4           3      House
# 99  Female      Greater than 3000         5           4  Apartment
#
#    PreferQuietPet Allergies PetChoice
# 0             Yes        No       Cat
# 1              No       Yes       Dog
# 2             Yes        No   Hamster
# 3              No        No      Fish
# 4             Yes       Yes     Snake
# ..            ...       ...       ...
# 95            Yes        No       Cat
# 96             No       Yes       Dog
# 97            Yes        No   Hamster
# 98             No        No      Fish
# 99            Yes       Yes     Snake
#
# [100 rows x 8 columns]

# %%
df_combined = pd.concat([df1, df2], ignore_index=True)
output_folder = "data_ready"
os.makedirs(output_folder, exist_ok=True)

output_path = os.path.join(output_folder, "pet_dataset_merged.csv")
df_combined.to_csv(output_path, index=False)

print(f"✅ ไฟล์รวมถูกบันทึกที่: {output_path}")
# Out:
# ✅ ไฟล์รวมถูกบันทึกที่: data_ready\pet_dataset_merged.csv

# %%
df_combined['PetChoice'].value_counts()
# Out:
# PetChoice
# Fish       22
# Dog        22
# Cat        22
# Snake      22
# Hamster    21
# No pet      3
# Name: count, dtype: int64
